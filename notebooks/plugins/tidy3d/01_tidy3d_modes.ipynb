# %% [markdown]
# # Tidy3D mode solver
#
# Tidy3d comes with an open source FDFD [mode solver](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/ModeSolver.html)
#
# ## Waveguides
#
# Guided Electromagnetic modes are the ones that have an effective index larger than the cladding of the waveguide
#
# Here is a waveguide of Silicon (n=3.4) surrounded by SiO2 (n=1.44) cladding
#
# For a 220 nm height x 450 nm width the effective index is 2.466

# %%
import numpy as np
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt
import gdsfactory as gf

gf.config.rich_output()
PDK = gf.generic_tech.get_generic_pdk()
PDK.activate()

nm = 1e-3
# Out:
# 2023-02-20 17:59:40.265 | INFO     | gdsfactory.config:<module>:50 - Load '/home/runner/work/gdsfactory/gdsfactory/gdsfactory' 6.43.1
# [17:59:42] INFO     Using client version: 1.8.4                                                     ]8;id=654125;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py\__init__.py]8;;\:]8;id=525617;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py#120\120]8;;\
# 2023-02-20 17:59:42.298 | INFO     | gdsfactory.simulation.gtidy3d:<module>:54 - Tidy3d '1.8.4' installed at ['/usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d']
# 2023-02-20 17:59:42.406 | INFO     | gdsfactory.technology.layer_views:__init__:785 - Importing LayerViews from YAML file: /home/runner/work/gdsfactory/gdsfactory/gdsfactory/generic_tech/layer_views.yaml.
# 2023-02-20 17:59:42.412 | INFO     | gdsfactory.pdk:activate:206 - 'generic' PDK is now active

# %%
strip = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore="si",
    nclad="sio2",
)
strip.plot_index()

# %%
strip.plot_Ex(0)  # TE
strip.plot_Ey(1)  # TM
# Out:
# 2023-02-20 17:59:42.759 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4a9b4373.npz mode data from file cache.

# %%
strip.neffs[0].real
# Out:
# 2.4658897

# %%
rib = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.15,
    ncore="si",
    nclad="sio2",
)
rib.plot_index()

# %%
rib.plot_Ex(mode_index=0)
rib.plot_Ey(mode_index=0)
# Out:
# 2023-02-20 17:59:43.578 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/e46296fc.npz mode data from file cache.

# %%
nitride = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=1.0,
    wg_thickness=0.4,
    slab_thickness=0.0,
    ncore="si",
    nclad="sio2",
)
nitride.plot_index()
nitride.plot_Ex(0)
nitride.plot_Ey(0)
# Out:
# 2023-02-20 17:59:44.393 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/7adb43be.npz mode data from file cache.

# %% [markdown]
# ## Sweep width
#
# You can sweep the waveguide width and compute the modes.
#
# By increasing the waveguide width, the waveguide supports many more TE and TM modes. Where TE modes have a dominant Ex field and TM modes have larger Ey fields.
#
# Notice that waveguides wider than 0.450 um support more than one TE mode. Therefore the maximum width for single mode operation is 0.450 um.

# %%
df = gt.modes.sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
gt.modes.plot_sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
plt.axhline(y=1.44, color="k", linestyle="--")
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-02-20 17:59:45.034 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/d2766683.npz mode data from file cache.
# 2023-02-20 17:59:45.056 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/53fce092.npz mode data from file cache.
# 2023-02-20 17:59:45.077 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/628302cb.npz mode data from file cache.
# 2023-02-20 17:59:45.098 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/e3e00794.npz mode data from file cache.
# 2023-02-20 17:59:45.120 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/fd0bf5de.npz mode data from file cache.
# 2023-02-20 17:59:45.142 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4ab9674b.npz mode data from file cache.
# 2023-02-20 17:59:45.163 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f747d95b.npz mode data from file cache.
# 2023-02-20 17:59:45.185 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/a4a16572.npz mode data from file cache.
# 2023-02-20 17:59:45.206 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/59ba7b0a.npz mode data from file cache.
# 2023-02-20 17:59:45.228 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/96276208.npz mode data from file cache.
# 2023-02-20 17:59:45.251 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/354c0080.npz mode data from file cache.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-02-20 17:59:45.287 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/d2766683.npz mode data from file cache.
# 2023-02-20 17:59:45.327 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/53fce092.npz mode data from file cache.
# 2023-02-20 17:59:45.355 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/628302cb.npz mode data from file cache.
# 2023-02-20 17:59:45.385 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/e3e00794.npz mode data from file cache.
# 2023-02-20 17:59:45.413 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/fd0bf5de.npz mode data from file cache.
# 2023-02-20 17:59:45.440 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4ab9674b.npz mode data from file cache.
# 2023-02-20 17:59:45.602 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f747d95b.npz mode data from file cache.
# 2023-02-20 17:59:45.630 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/a4a16572.npz mode data from file cache.
# 2023-02-20 17:59:45.659 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/59ba7b0a.npz mode data from file cache.
# 2023-02-20 17:59:45.694 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/96276208.npz mode data from file cache.
# 2023-02-20 17:59:45.724 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/354c0080.npz mode data from file cache.

# %% [markdown]
# **Exercises**
#
# - What is the maximum width to support a single TE mode at 1310 nm?
# - For a Silicon Nitride (n=2) 400nm thick waveguide surrounded by SiO2 (n=1.44), what is the maximum width to support a single TE mode at 1550 nm?
# - For two 500x220nm Silicon waveguides surrounded by SiO2, what is the coupling length (100% coupling) for 200 nm gap?

# %% [markdown]
# ## Group index
#
# You can also compute the group index for a waveguide.

# %%
nm = 1e-3

ng = gt.modes.group_index(
    wg_width=500 * nm,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
print(ng)
# Out:
# 2023-02-20 17:59:46.324 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4a9b4373.npz mode data from file cache.
# 2023-02-20 17:59:46.343 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/ba607431.npz mode data from file cache.
# 2023-02-20 17:59:46.362 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/a7a6b1cb.npz mode data from file cache.
# 4.1703596115112305

# %%
nm = 1e-3
wg_widths = np.array([490, 500, 510]) * nm
wg_settings = dict(
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)

ng = [
    gt.modes.group_index(wavelength=1550 * nm, wg_width=wg_width, **wg_settings)
    for wg_width in wg_widths
]
plt.plot(wg_widths * 1e3, ng)
plt.xlabel("waveguide width (nm)")
plt.ylabel("ng")
# Out:
# 2023-02-20 17:59:46.391 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/a7025450.npz mode data from file cache.
# 2023-02-20 17:59:46.411 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/df90e03b.npz mode data from file cache.
# 2023-02-20 17:59:46.431 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/5b5db443.npz mode data from file cache.
# 2023-02-20 17:59:46.450 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4a9b4373.npz mode data from file cache.
# 2023-02-20 17:59:46.468 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/ba607431.npz mode data from file cache.
# 2023-02-20 17:59:46.486 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/a7a6b1cb.npz mode data from file cache.
# 2023-02-20 17:59:46.506 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/366f0a8f.npz mode data from file cache.
# 2023-02-20 17:59:46.526 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/52834c6b.npz mode data from file cache.
# 2023-02-20 17:59:46.546 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/cd7297fb.npz mode data from file cache.

# %% [markdown]
# ## Bend modes
#
# You can compute bend modes specifying the bend radius.

# %%
strip_bend = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius=3,
    ncore="si",
    nclad="sio2",
)

# %%
# plot the fundamental TE mode
strip_bend.plot_Ex(0)
strip_bend.plot_Ey(0)
# Out:
# 2023-02-20 17:59:46.728 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/6407f851.npz mode data from file cache.

# %%
# plot the fundamental TM mode
strip_bend.plot_Ex(1)
strip_bend.plot_Ey(1)

# %% [markdown]
# ## Bend loss
#
# You can also compute the losses coming from the mode mismatch from the bend into a straight waveguide.
# To compute the bend loss due to mode mismatch you can calculate the mode overlap of the straight mode and the bent mode.
# Because there are two mode mismatch interfaces the total loss due to mode mismatch will be squared (from bend to straight and from straight to bend).
#
# ![](https://i.imgur.com/M1Yysdr.png)
#
# [from paper](https://ieeexplore.ieee.org/ielaam/50/8720127/8684870-aam.pdf)

# %%
r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius_min=2.0,
    bend_radius_max=5,
    steps=4,
    mode_index=0,
    ncore="si",
    nclad="sio2",
)

plt.title("Bend90 loss for TE polarization")
plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2023-02-20 17:59:47.922 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4a9b4373.npz mode data from file cache.
# 2023-02-20 17:59:47.946 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/19e337b7.npz mode data from file cache.
# 2023-02-20 17:59:47.966 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/6407f851.npz mode data from file cache.
# 2023-02-20 17:59:47.990 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/c67ad8a9.npz mode data from file cache.
# 2023-02-20 17:59:48.012 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f62618ff.npz mode data from file cache.

# %%
dB_cm = 2  # dB/cm
length = 2 * np.pi * r * 1e-6
propagation_loss = dB_cm * length * 1e2
propagation_loss
# Out:
# array([0.00251327, 0.00376991, 0.00502655, 0.00628319])

# %%
plt.title("Bend90 loss for TE polarization")
plt.plot(r, -10 * np.log10(integral), ".", label="mode loss")
plt.plot(r, propagation_loss, ".", label="propagation loss")
plt.xlabel("bend radius (um)")
plt.ylabel("Loss (dB)")
plt.legend()

# %%
r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius_min=3.0,
    bend_radius_max=20,
    steps=4,
    mode_index=1,
    ncore="si",
    nclad="sio2",
)

plt.title("Bend90 loss for TM polarization")
plt.ylim(ymin=min(integral), ymax=1)
plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2023-02-20 17:59:48.395 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4a9b4373.npz mode data from file cache.
# 2023-02-20 17:59:48.416 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/6407f851.npz mode data from file cache.
# 2023-02-20 17:59:48.440 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/dd729f10.npz mode data from file cache.
# 2023-02-20 17:59:48.463 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/aef4d5e0.npz mode data from file cache.
# 2023-02-20 17:59:48.488 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/b741a7dc.npz mode data from file cache.

# %%
dB_cm = 1  # dB/cm
length = 2 * np.pi * r * 1e-6
propagation_loss = dB_cm * length * 1e2
propagation_loss
# Out:
# array([0.00188496, 0.00544543, 0.0090059 , 0.01256637])

# %%
plt.plot(r, -10 * np.log10(integral), ".", label="mode loss")
plt.plot(r, propagation_loss, ".", label="propagation loss")
plt.title("Bend90 loss for TM polarization")
plt.xlabel("bend radius (um)")
plt.ylabel("Loss (dB)")
plt.legend()

# %% [markdown]
# **Exercises**
#
# - For a 500nm wide 220nm thick Silicon waveguide surrounded by SiO2, what is the minimum bend radius to have less than 0.04dB loss for TE polarization at 1550nm?
# - For a 500nm wide 220nm thick Silicon waveguide surrounded by SiO2, what is the minimum bend radius to have 99% power transmission for TM polarization at 1550nm?

# %% [markdown]
# ## Waveguide coupler
#
# You can also compute the modes of a waveguide coupler.
#
# ```
#         wg_width1     wg_width2
#         <------->     <------->
#          _______       _______   _
#         |       |     |       | |
#         |       |     |       |
#         |       |_____|       | | wg_thickness
#         |slab_thickness       |
#         |_____________________| |_
#                 <----->
#                   gap
#
#
# ```

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=100 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
c.plot_Ex(0, plot_power=False)  # even
c.plot_Ex(1, plot_power=False)  # odd
# Out:
# 2023-02-20 17:59:49.034 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/4c6fc5c5.npz mode data from file cache.

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
c.plot_Ex(0, plot_power=False)  # even
c.plot_Ex(1, plot_power=False)  # odd
# Out:
# 2023-02-20 17:59:49.951 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f359d64b.npz mode data from file cache.

# %%
nm = 1e-3
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
gaps = [150, 200, 250, 300]
coupling_length = [
    gt.modes.WaveguideCoupler(
        wavelength=1.55,
        wg_width1=500 * nm,
        wg_width2=500 * nm,
        gap=gap * nm,
        wg_thickness=220 * nm,
        slab_thickness=0 * nm,
        ncore="si",
        nclad="sio2",
    ).find_coupling(power_ratio=1)
    for gap in gaps
]
# Out:
# 2023-02-20 17:59:50.737 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/606b2f09.npz mode data from file cache.
# 2023-02-20 17:59:50.756 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f359d64b.npz mode data from file cache.
# 2023-02-20 17:59:50.777 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/63f04e5a.npz mode data from file cache.
# 2023-02-20 17:59:50.797 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/87a2a566.npz mode data from file cache.

# %%
plt.plot(gaps, coupling_length, ".")
plt.xlabel("gap (nm)")
plt.ylabel("100% coupling length (um)")

# %%
df = gt.modes.find_coupling_vs_gap(
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
df
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 2023-02-20 17:59:50.970 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/f359d64b.npz mode data from file cache.
# 2023-02-20 17:59:50.989 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/fcb86125.npz mode data from file cache.
# 2023-02-20 17:59:51.007 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/aaf07c4a.npz mode data from file cache.
# 2023-02-20 17:59:51.025 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/31b76c44.npz mode data from file cache.
# 2023-02-20 17:59:51.043 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/2f4e3e77.npz mode data from file cache.
# 2023-02-20 17:59:51.062 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/33e70421.npz mode data from file cache.
# 2023-02-20 17:59:51.080 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/fad263ef.npz mode data from file cache.
# 2023-02-20 17:59:51.099 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/33b49974.npz mode data from file cache.
# 2023-02-20 17:59:51.117 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/e4bc7a19.npz mode data from file cache.
# 2023-02-20 17:59:51.136 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/d1c02ec7.npz mode data from file cache.
# 2023-02-20 17:59:51.154 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/708b93c3.npz mode data from file cache.
# 2023-02-20 17:59:51.173 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:439 - load /home/runner/.gdsfactory/modes/932ed1c4.npz mode data from file cache.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gap</th>
#       <th>ne</th>
#       <th>no</th>
#       <th>lc</th>
#       <th>dn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.200000</td>
#       <td>2.430307</td>
#       <td>2.403961</td>
#       <td>29.415999</td>
#       <td>0.026346</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.218182</td>
#       <td>2.434447</td>
#       <td>2.408951</td>
#       <td>30.397202</td>
#       <td>0.025496</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.236364</td>
#       <td>2.460559</td>
#       <td>2.448616</td>
#       <td>64.893606</td>
#       <td>0.011943</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.254545</td>
#       <td>2.464516</td>
#       <td>2.452997</td>
#       <td>67.281800</td>
#       <td>0.011519</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.272727</td>
#       <td>2.430179</td>
#       <td>2.416353</td>
#       <td>56.053277</td>
#       <td>0.013826</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.290909</td>
#       <td>2.444588</td>
#       <td>2.432067</td>
#       <td>61.894695</td>
#       <td>0.012521</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.309091</td>
#       <td>2.435488</td>
#       <td>2.428164</td>
#       <td>105.820223</td>
#       <td>0.007324</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.327273</td>
#       <td>2.439679</td>
#       <td>2.432644</td>
#       <td>110.152003</td>
#       <td>0.007036</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.345455</td>
#       <td>2.443704</td>
#       <td>2.437016</td>
#       <td>115.889536</td>
#       <td>0.006687</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.363636</td>
#       <td>2.447752</td>
#       <td>2.441331</td>
#       <td>120.682591</td>
#       <td>0.006422</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.381818</td>
#       <td>2.439935</td>
#       <td>2.436173</td>
#       <td>206.007073</td>
#       <td>0.003762</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.400000</td>
#       <td>2.454328</td>
#       <td>2.450968</td>
#       <td>230.701604</td>
#       <td>0.003359</td>
#     </tr>
#   </tbody>
# </table>
# </div>
